# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.animation as animation
import json

# %%
table = pd.read_csv('output.csv', delimiter=',')

# %%
table = table.loc[table['i'] != 121]
table
# Out:
#       avg len  diameter  nodes     edges   density  degree     i
# 0    1.500000         2      5         5  0.500000       2     5
# 1    1.250000         2      9        27  0.750000       6     9
# 2    1.500000         2     13        39  0.500000       6    13
# 3    1.500000         2     17        68  0.500000       8    17
# 4    1.583333         2     25       125  0.416667      10    25
# ..        ...       ...    ...       ...       ...     ...   ...
# 495  1.500000         2   7457  13899848  0.500000    3728  7457
# 496  1.500000         2   7477  13974513  0.500000    3738  7477
# 497  1.500000         2   7481  13989470  0.500000    3740  7481
# 498  1.500000         2   7489  14019408  0.500000    3744  7489
# 499  1.500000         2   7517  14124443  0.500000    3758  7517
#
# [499 rows x 7 columns]

# %%
arr=table.transpose().to_numpy()

# %%
j=arr[6]

# %%
l1=[]
l2=[]
l3=[]
l4=[]
l5=[]
l6=[]
l7=[]
l8=[]
l9=[]
l10=[]
l11=[]
l12=[]
l13=[]
l14=[]
l15=[]
l16=[]
l17=[]
l18=[]
l19=[]
l20=[]
l0=[]

# %%
plt.style.use("seaborn-bright")
fig = plt.figure(figsize=(5, 5))
ax = plt.axes(polar=True)
ax.set_rmax(100)
ax.set_rticks([])
# Out:
# <ipython-input-7-9c3bffea75db>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-bright")
# []

# %%
for i in list(j):
        if i % 44 == 1:
            l1.append(i)
            ax.plot(l1, l1)
        elif i % 44 == 3:
            l2.append(i)
            ax.plot(l2, l2)
        elif i % 44 == 5:
            l3.append(i)
            ax.plot(l3, l3)
        elif i % 44 == 7:
            l4.append(i)
            ax.plot(l4, l4)
        elif i % 44 == 9:
            l5.append(i)
            ax.plot(l5, l5)
        elif i % 44 == 13:
            l6.append(i)
            ax.plot(l6, l6)
        elif i % 44 == 15:
            l7.append(i)
            ax.plot(l7, l7)
        elif i % 44 == 17:
            l8.append(i)
            ax.plot(l8, l8)
        elif i % 44 == 19:
            l9.append(i)
            ax.plot(l9, l9)
        elif i % 44 == 21:
            l10.append(i)
            ax.plot(l10, l10)
        elif i % 44 == 23:
            l11.append(i)
            ax.plot(l11, l11)
        elif i % 44 == 25:
            l12.append(i)
            ax.plot(l12, l12)
        elif i % 44 == 27:
            l13.append(i)
            ax.plot(l13, l13)
        elif i % 44 == 29:
            l14.append(i)
            ax.plot(l14, l14)
        elif i % 44 == 31:
            l15.append(i)
            ax.plot(l15, l15)
        elif i % 44 == 35:
            l16.append(i)
            ax.plot(l16, l16)
        elif i % 44 == 37:
            l17.append(i)
            ax.plot(l17, l17)
        elif i % 44 == 39:
            l18.append(i)
            ax.plot(l18, l18)
        elif i % 44 == 41:
            l19.append(i)
            ax.plot(l19, l19)
        elif i % 44 == 43:
            l20.append(i)
            ax.plot(l20, l20)
        else:
            l0.append(i)
        ax.scatter(i, i, s=5, c="white")

# %%
ax.text(l1[len(l1)-1], l1[len(l1)-1], '1', fontsize = 8)

ax.text(l3[len(l3)-1], l3[len(l3)-1], '2', fontsize = 8)

ax.text(l5[len(l5)-1], l5[len(l5)-1], '3', fontsize = 8)
ax.text(l6[len(l6)-1], l6[len(l6)-1], '4', fontsize = 8)

ax.text(l8[len(l8)-1], l8[len(l8)-1], '5', fontsize = 8)

ax.text(l10[len(l10)-1], l10[len(l10)-1], '6', fontsize = 8)

ax.text(l12[len(l12)-1], l12[len(l12)-1], '7', fontsize = 8)

ax.text(l14[len(l14)-1], l14[len(l14)-1], '8', fontsize = 8)

ax.text(l17[len(l17)-1], l17[len(l17)-1], '9', fontsize = 8)

ax.text(l19[len(l19)-1], l19[len(l19)-1], '10', fontsize = 8)
# Out:
# Text(7477.0, 7477.0, '10')

# %%
fig

# %%
fig.savefig('lines')
