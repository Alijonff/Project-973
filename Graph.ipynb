# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.animation as animation

# %%
table = pd.read_csv('output.csv', delimiter=',')

# %%
table = table.loc[table['i'] != 121]
table
# Out:
#       avg len  diameter  nodes     edges   density  degree     i
# 0    1.500000         2      5         5  0.500000       2     5
# 1    1.250000         2      9        27  0.750000       6     9
# 2    1.500000         2     13        39  0.500000       6    13
# 3    1.500000         2     17        68  0.500000       8    17
# 4    1.583333         2     25       125  0.416667      10    25
# ..        ...       ...    ...       ...       ...     ...   ...
# 495  1.500000         2   7457  13899848  0.500000    3728  7457
# 496  1.500000         2   7477  13974513  0.500000    3738  7477
# 497  1.500000         2   7481  13989470  0.500000    3740  7481
# 498  1.500000         2   7489  14019408  0.500000    3744  7489
# 499  1.500000         2   7517  14124443  0.500000    3758  7517
#
# [499 rows x 7 columns]

# %%
arr=table.transpose().to_numpy()

# %%
j=arr[6]

# %%
len(j)
# Out:
# 499

# %%
l1=[]
l2=[]
l3=[]
l4=[]
l5=[]
l6=[]
l7=[]
l8=[]
l9=[]
l10=[]
l11=[]
l12=[]
l13=[]
l14=[]
l15=[]
l16=[]
l17=[]
l18=[]
l19=[]
l20=[]
l0=[]

# %%
for i in list(j):
        if i % 44 == 1:
            l1.append(i)
        elif i % 44 == 3:
            l2.append(i)
        elif i % 44 == 5:
            l3.append(i)
        elif i % 44 == 7:
            l4.append(i)
        elif i % 44 == 9:
            l5.append(i)
        elif i % 44 == 13:
            l6.append(i)
        elif i % 44 == 15:
            l7.append(i)
        elif i % 44 == 17:
            l8.append(i)
        elif i % 44 == 19:
            l9.append(i)
        elif i % 44 == 21:
            l10.append(i)
        elif i % 44 == 23:
            l11.append(i)
        elif i % 44 == 25:
            l12.append(i)
        elif i % 44 == 27:
            l13.append(i)
        elif i % 44 == 29:
            l14.append(i)
        elif i % 44 == 31:
            l15.append(i)
        elif i % 44 == 35:
            l16.append(i)
        elif i % 44 == 37:
            l17.append(i)
        elif i % 44 == 39:
            l18.append(i)
        elif i % 44 == 41:
            l19.append(i)
        elif i % 44 == 43:
            l20.append(i)
        else:
            l0.append(i)

# %%
print('1', len(l1), l1)
print('2', len(l3), l3)
print('3', len(l5), l5)
print('4', len(l6), l6)
print('5', len(l8), l8)
print('6', len(l10), l10)
print('7', len(l12), l12)
print('8', len(l14), l14)
print('9', len(l17), l17)
print('10', len(l19), l19)
print('0', len(l0), l0)
# Out:
# 1 50 [89.0, 353.0, 397.0, 529.0, 617.0, 661.0, 881.0, 1013.0, 1277.0, 1321.0, 1409.0, 1453.0, 1849.0, 2069.0, 2113.0, 2333.0, 2377.0, 2729.0, 2861.0, 3037.0, 3125.0, 3169.0, 3257.0, 3301.0, 3389.0, 3433.0, 3697.0, 3917.0, 4049.0, 4093.0, 4357.0, 4489.0, 4621.0, 4973.0, 5237.0, 5281.0, 5413.0, 5501.0, 5897.0, 6029.0, 6073.0, 6337.0, 6469.0, 6689.0, 6733.0, 6997.0, 7129.0, 7349.0, 7393.0, 7481.0]
# 2 55 [5.0, 49.0, 137.0, 181.0, 269.0, 313.0, 401.0, 577.0, 709.0, 797.0, 841.0, 929.0, 1061.0, 1193.0, 1237.0, 1369.0, 1721.0, 2029.0, 2161.0, 2293.0, 2381.0, 2557.0, 2689.0, 2777.0, 2909.0, 2953.0, 3041.0, 3217.0, 3481.0, 3613.0, 3701.0, 3833.0, 3877.0, 4229.0, 4273.0, 4493.0, 4801.0, 4889.0, 4933.0, 5021.0, 5153.0, 5197.0, 5329.0, 5417.0, 5813.0, 5857.0, 6121.0, 6473.0, 6561.0, 6737.0, 6781.0, 6869.0, 7001.0, 7177.0, 7309.0]
# ...

# %%
print('1', len(l1), l1)
print('2', len(l2), l2)
print('3', len(l3), l3)
print('4', len(l4), l4)
print('5', len(l5), l5)
print('6', len(l6), l6)
print('7', len(l7), l7)
print('8', len(l8), l8)
print('9', len(l9), l9)
print('10', len(l10), l10)
print('11', len(l11), l11)
print('12', len(l12), l12)
print('13', len(l13), l13)
print('14', len(l14), l14)
print('15', len(l15), l15)
print('16', len(l16), l16)
print('17', len(l17), l17)
print('18', len(l18), l18)
print('19', len(l19), l19)
print('20', len(l20), l20)
print('0', len(l0), l0)
# Out:
# 1 50 [89.0, 353.0, 397.0, 529.0, 617.0, 661.0, 881.0, 1013.0, 1277.0, 1321.0, 1409.0, 1453.0, 1849.0, 2069.0, 2113.0, 2333.0, 2377.0, 2729.0, 2861.0, 3037.0, 3125.0, 3169.0, 3257.0, 3301.0, 3389.0, 3433.0, 3697.0, 3917.0, 4049.0, 4093.0, 4357.0, 4489.0, 4621.0, 4973.0, 5237.0, 5281.0, 5413.0, 5501.0, 5897.0, 6029.0, 6073.0, 6337.0, 6469.0, 6689.0, 6733.0, 6997.0, 7129.0, 7349.0, 7393.0, 7481.0]
# 2 0 []
# 3 55 [5.0, 49.0, 137.0, 181.0, 269.0, 313.0, 401.0, 577.0, 709.0, 797.0, 841.0, 929.0, 1061.0, 1193.0, 1237.0, 1369.0, 1721.0, 2029.0, 2161.0, 2293.0, 2381.0, 2557.0, 2689.0, 2777.0, 2909.0, 2953.0, 3041.0, 3217.0, 3481.0, 3613.0, 3701.0, 3833.0, 3877.0, 4229.0, 4273.0, 4493.0, 4801.0, 4889.0, 4933.0, 5021.0, 5153.0, 5197.0, 5329.0, 5417.0, 5813.0, 5857.0, 6121.0, 6473.0, 6561.0, 6737.0, 6781.0, 6869.0, 7001.0, 7177.0, 7309.0]
# 4 0 []
# ...

# %%
claster = j

# %%
for i in range(len(claster)):
  for j in range(len(l1)):
    if claster[i]==l1[j]:
      claster[i]=1
for i in range(len(claster)):
  for j in range(len(l3)):
    if claster[i]==l3[j]:
      claster[i]=2
for i in range(len(claster)):
  for j in range(len(l5)):
    if claster[i]==l5[j]:
      claster[i]=3
for i in range(len(claster)):
  for j in range(len(l6)):
    if claster[i]==l6[j]:
      claster[i]=4
for i in range(len(claster)):
  for j in range(len(l8)):
    if claster[i]==l8[j]:
      claster[i]=5
for i in range(len(claster)):
  for j in range(len(l10)):
    if claster[i]==l10[j]:
      claster[i]=6
for i in range(len(claster)):
  for j in range(len(l12)):
    if claster[i]==l12[j]:
      claster[i]=7
for i in range(len(claster)):
  for j in range(len(l14)):
    if claster[i]==l14[j]:
      claster[i]=8
for i in range(len(claster)):
  for j in range(len(l17)):
    if claster[i]==l17[j]:
      claster[i]=9
for i in range(len(claster)):
  for j in range(len(l19)):
    if claster[i]==l19[j]:
      claster[i]=10

# %%
claster
# Out:
# array([ 2.,  3.,  4.,  5.,  7.,  8.,  9., 10.,  2.,  3.,  5.,  8.,  9.,
#         1.,  3.,  4.,  6.,  7.,  9.,  2.,  5.,  7.,  9., 10.,  2.,  5.,
#         6.,  3.,  4.,  6.,  9.,  2.,  4.,  5.,  7.,  8.,  2.,  3.,  8.,
#        10.,  1.,  3.,  6.,  9.,  1.,  2.,  4.,  7.,  9.,  3.,  5.,  6.,
#         7.,  9.,  1.,  4.,  8., 10.,  2.,  6.,  8., 10.,  1.,  3.,  7.,
#         9.,  1.,  4.,  5., 10.,  2.,  7.,  8.,  3.,  4.,  6.,  7.,  2.,
#         5.,  8.,  9.,  2.,  5.,  6., 10.,  1.,  2.,  4.,  5.,  8.,  9.,
#         3.,  8., 10.,  1.,  3.,  6.,  9.,  2.,  4.,  9., 10.,  3.,  5.,
#         8.,  3.,  9.,  2.,  4.,  7.,  8., 10.,  2.,  5.,  1.,  4.,  6.,
#         7.,  1., 10.,  2.,  3.,  5.,  1.,  6.,  7.,  1.,  8.,  9., 10.,
#         3.,  4.,  4.,  5.,  7.,  8.,  9.,  3.,  8., 10.,  3.,  6.,  7.,
#         9.,  2.,  5.,  7.,  9.,  5.,  8., 10.,  1.,  4.,  7.,  8., 10.,
#         3.,  6., 10.,  4.,  9.,  4.,  5.,  9.,  2.,  8.,  1.,  4.,  6.,
# ...

# %%
table['class'] = claster
table
# Out:
#       avg len  diameter  nodes     edges   density  degree     i  class
# 0    1.500000         2      5         5  0.500000       2     5    2.0
# 1    1.250000         2      9        27  0.750000       6     9    3.0
# 2    1.500000         2     13        39  0.500000       6    13    4.0
# 3    1.500000         2     17        68  0.500000       8    17    5.0
# 4    1.583333         2     25       125  0.416667      10    25    7.0
# ..        ...       ...    ...       ...       ...     ...   ...    ...
# 495  1.500000         2   7457  13899848  0.500000    3728  7457    6.0
# 496  1.500000         2   7477  13974513  0.500000    3738  7477   10.0
# 497  1.500000         2   7481  13989470  0.500000    3740  7481    1.0
# 498  1.500000         2   7489  14019408  0.500000    3744  7489    3.0
# 499  1.500000         2   7517  14124443  0.500000    3758  7517    9.0
#
# [499 rows x 8 columns]

# %%
table1 = table.loc[table['class'] == 1]
table2 = table.loc[table['class'] == 2]
table3 = table.loc[table['class'] == 3]
table4 = table.loc[table['class'] == 4]
table5 = table.loc[table['class'] == 5]
table6 = table.loc[table['class'] == 6]
table7 = table.loc[table['class'] == 7]
table8 = table.loc[table['class'] == 8]
table9 = table.loc[table['class'] == 9]
table10 = table.loc[table['class'] == 10]

# %%
arr1=table1.transpose().to_numpy()
arr2=table2.transpose().to_numpy()
arr3=table3.transpose().to_numpy()
arr4=table4.transpose().to_numpy()
arr5=table5.transpose().to_numpy()
arr6=table6.transpose().to_numpy()
arr7=table7.transpose().to_numpy()
arr8=table8.transpose().to_numpy()
arr9=table9.transpose().to_numpy()
arr10=table10.transpose().to_numpy()

# %%
table.describe()
# Out:
#           avg len  diameter        nodes         edges     density  \
# count  499.000000     499.0   499.000000  4.990000e+02  499.000000
# mean     1.487994       2.0  3432.126253  4.273944e+06    0.512006
# std      0.074480       0.0  2233.043035  4.317393e+06    0.074480
# min      1.011905       2.0     5.000000  5.000000e+00    0.416667
# 25%      1.500000       2.0  1431.000000  5.115835e+05    0.500000
# 50%      1.500000       2.0  3301.000000  2.723325e+06    0.500000
# 75%      1.500000       2.0  5357.000000  7.296776e+06    0.500000
# max      1.583333       2.0  7517.000000  2.344327e+07    0.988095
#
#             degree            i       class
# count   499.000000   499.000000  499.000000
# mean   1750.781563  3432.126253    5.452906
# std    1173.217382  2233.043035    2.881754
# min       2.000000     5.000000    1.000000
# 25%     721.000000  1431.000000    3.000000
# 50%    1680.000000  3301.000000    5.000000
# 75%    2707.000000  5357.000000    8.000000
# ...

# %%
fig, ax = plt.subplots(figsize=(15, 15))
plt.plot(arr1[6], arr1[0], label='1')
plt.plot(arr2[6], arr2[0], label='2')
plt.plot(arr3[6], arr3[0], label='3')
plt.plot(arr4[6], arr4[0], label='4')
plt.plot(arr5[6], arr5[0], label='5')
plt.plot(arr6[6], arr6[0], label='6')
plt.plot(arr7[6], arr7[0], label='7')
plt.plot(arr8[6], arr8[0], label='8')
plt.plot(arr9[6], arr9[0], label='9')
plt.plot(arr10[6], arr10[0], label='10')
plt.xlabel('Nodes', fontsize=20)
plt.ylabel('Average length', fontsize=20)
plt.legend(prop={'size': 15}, title = 'Groups', title_fontsize = '15')
plt.tick_params(axis='both', which='major', labelsize=15)
ax.xaxis.set_major_locator(ticker.MultipleLocator(500))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(100))
ax.yaxis.set_major_locator(ticker.MultipleLocator(0.1))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.02))
plt.show()
